# %%
# %matplotlib inline
import pandas as pd # Import for Pandas
import numpy as np # Import for Numpy
import matplotlib # Import for Matplotlib
import matplotlib.pyplot as plt # Import for Matplotlib Pyplot
import seaborn as sns # Import for Seaborn

# %% [markdown]
# Downloading the dataset...
#
#
# What kind or information you'll get ?
# The download will include information about your:
#
# 1. Identity
# 2. Inferences
# 3. User Data
# 4. Playlists
# 5. Streaming History
# 6. Searches
# 7. List of items saved in Your Library
# 8. Number of followers you have
# 9. Number of accounts you follow
# 10. Names of the artists you follow
# 11. Payment and subscription data.

# %%
df = pd.read_json("/content/StreamingHistory0.json") # Load the JSON File into a dataframe
df.head() # Read first few lines of the dataframe
# Out:
#             endTime     artistName               trackName  msPlayed
# 0  2021-07-30 00:06      Mas Musiq                 Mthande    377935
# 1  2021-07-30 00:12      Beast Rsa                Pepereza    341052
# 2  2021-07-30 00:19  Reece Madlisa  Jazzidisciples (Zlele)    457000
# 3  2021-07-30 00:31  Reece Madlisa             Sithi Sithi    728885
# 4  2021-07-30 00:39      DJ Tarico             Yaba Buluku    411480

# %%
#Import data
df1 = pd.read_json("StreamingHistory0.json") # Read the first file

# %%
df1.head() # To read top 5 rows of the first dataframe
# Out:
#             endTime     artistName               trackName  msPlayed
# 0  2021-07-30 00:06      Mas Musiq                 Mthande    377935
# 1  2021-07-30 00:12      Beast Rsa                Pepereza    341052
# 2  2021-07-30 00:19  Reece Madlisa  Jazzidisciples (Zlele)    457000
# 3  2021-07-30 00:31  Reece Madlisa             Sithi Sithi    728885
# 4  2021-07-30 00:39      DJ Tarico             Yaba Buluku    411480

# %%
df1.tail() # To read bottom 5 rows of the first dataframe
# Out:
#                endTime       artistName  \
# 9995  2021-12-23 04:15    Muzzy D Pilot
# 9996  2021-12-23 04:16      Kamo Mphela
# 9997  2021-12-23 04:24  Mellow & Sleazy
# 9998  2021-12-23 04:29        King Zeph
# 9999  2021-12-23 04:42    Reece Madlisa
#
#                                               trackName  msPlayed
# 9995                           Shay'mpempe amapiano mix    204126
# 9996                                         Nkulunkulu      1150
# 9997  Bopha (feat. DJ Maphorisa, Madumane & Young St...    463446
# 9998                                  Denzel Washington    340884
# 9999                                            Bazooka    177855

# %%
#Merging all of the data together
spotify_stream_df = pd.concat([df1], ignore_index=True) # To concatenate the two dataframes
spotify_stream_df.to_csv("spotify_data_3.csv") # To save csv data

# %%
spotify_stream_df # To read all the dataframe at once
# Out:
#                endTime       artistName  \
# 0     2021-07-30 00:06        Mas Musiq
# 1     2021-07-30 00:12        Beast Rsa
# 2     2021-07-30 00:19    Reece Madlisa
# 3     2021-07-30 00:31    Reece Madlisa
# 4     2021-07-30 00:39        DJ Tarico
# ...                ...              ...
# 9995  2021-12-23 04:15    Muzzy D Pilot
# 9996  2021-12-23 04:16      Kamo Mphela
# 9997  2021-12-23 04:24  Mellow & Sleazy
# 9998  2021-12-23 04:29        King Zeph
# 9999  2021-12-23 04:42    Reece Madlisa
#
#                                               trackName  msPlayed
# 0                                               Mthande    377935
# 1                                              Pepereza    341052
# 2                                Jazzidisciples (Zlele)    457000
# 3                                           Sithi Sithi    728885
# 4                                           Yaba Buluku    411480
# ...                                                 ...       ...
# 9995                           Shay'mpempe amapiano mix    204126
# 9996                                         Nkulunkulu      1150
# 9997  Bopha (feat. DJ Maphorisa, Madumane & Young St...    463446
# 9998                                  Denzel Washington    340884
# 9999                                            Bazooka    177855
#
# [10000 rows x 4 columns]

# %%
spotify_stream_df.shape
# Out:
# (10000, 4)

# %%
spotify_stream_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   endTime     10000 non-null  object
#  1   artistName  10000 non-null  object
#  2   trackName   10000 non-null  object
#  3   msPlayed    10000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
spotify_stream_df.nunique() # To see the unique elemetns present in each column
# Out:
# endTime       8398
# artistName    2363
# trackName     3949
# msPlayed      5781
# dtype: int64

# %%
spotify_stream_df.sample(10) # To check a sample of the data
# Out:
#                endTime                artistName  \
# 5429  2021-10-12 18:24           Little Circuits
# 3591  2021-09-13 22:12      Clouded Transparency
# 2013  2021-08-25 10:35                    A-Star
# 7412  2021-11-07 08:24                    Davido
# 4180  2021-09-21 17:15         Stories of Dharma
# 2019  2021-08-25 14:15  The Joe Rogan Experience
# 7750  2021-11-11 18:05        The Blue Room Band
# 1895  2021-08-25 00:17                    Blanco
# 7962  2021-11-14 06:27                  Omah Lay
# 3833  2021-09-15 03:38                      JAE5
#
#                             trackName  msPlayed
# 5429            Beautiful Imagination    143000
# 3591                     The Lost Key    160722
# 2013                     Baako Riddim     97374
# 7412                          1 Milli    163702
# 4180                           Tiempo    325238
# 2019              #1691 - Yeonmi Park     52771
# 7750                            Emily    293970
# 1895         Surveillance (feat. NSG)      1821
# 7962                     Free My Mind      1593
# 3833  Dimension (feat. Skepta & Rema)    234026

# %%
len(spotify_stream_df["artistName"].unique()) # Length of unique artist
# Out:
# 2363

# %%
len(spotify_stream_df["trackName"].unique()) # Length of unique tracks
# Out:
# 3949

# %%
#Cleaning and formatting
spotify_stream_df["Play-Time"]= pd.to_datetime(spotify_stream_df["endTime"]) # To create a additional column

# %%
spotify_stream_df['year'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).year
spotify_stream_df['month'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).month
spotify_stream_df['day'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).day
spotify_stream_df['weekday'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).weekday
spotify_stream_df['time'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).time
spotify_stream_df['hours'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).hour
spotify_stream_df['day-name'] = spotify_stream_df["Play-Time"].apply(lambda x: x.day_name())
spotify_stream_df['Count'] = 1

# %% [markdown]
# Here we used the DatetimeIndex module to obatin the several unique information. We also added them to a new columns as per their representaion and information.
#
# Information contained in different columns :
#
# 1. year has information about the year when we played that song
# 2. month has information about the month when we played that song
# 3. weekday has information about the weekday when we played that song
# 4. time has information about the time when we played that song
# 5. hours has information about the hour when we played that song
# 6. day-name has information about the day with the name when we played that
# 7.  song. Here we used apply method for pandas dataframe with lambda function.

# %%
spotify_stream_df["Time-Played (hh-mm-ss)"] = pd.to_timedelta(spotify_stream_df["msPlayed"], unit='ms')

# %%
def hours(td):
    '''To get the hour information'''
    return td.seconds/3600

def minutes(td):
    '''To get the minutes information'''
    return (td.seconds/60)%60

spotify_stream_df["Listening Time(Hours)"] = spotify_stream_df["Time-Played (hh-mm-ss)"].apply(hours).round(3)
spotify_stream_df["Listening Time(Minutes)"] = spotify_stream_df["Time-Played (hh-mm-ss)"].apply(minutes).round(3)

# %%
spotify_stream_df.head() # To check the newly formed dataset with additional columns
# Out:
#             endTime     artistName               trackName  msPlayed  \
# 0  2021-07-30 00:06      Mas Musiq                 Mthande    377935
# 1  2021-07-30 00:12      Beast Rsa                Pepereza    341052
# 2  2021-07-30 00:19  Reece Madlisa  Jazzidisciples (Zlele)    457000
# 3  2021-07-30 00:31  Reece Madlisa             Sithi Sithi    728885
# 4  2021-07-30 00:39      DJ Tarico             Yaba Buluku    411480
#
#             Play-Time  year  month  day  weekday      time  hours day-name  \
# 0 2021-07-30 00:06:00  2021      7   30        4  00:06:00      0   Friday
# 1 2021-07-30 00:12:00  2021      7   30        4  00:12:00      0   Friday
# 2 2021-07-30 00:19:00  2021      7   30        4  00:19:00      0   Friday
# 3 2021-07-30 00:31:00  2021      7   30        4  00:31:00      0   Friday
# 4 2021-07-30 00:39:00  2021      7   30        4  00:39:00      0   Friday
#
#    Count Time-Played (hh-mm-ss)  Listening Time(Hours)  \
# 0      1 0 days 00:06:17.935000                  0.105
# 1      1 0 days 00:05:41.052000                  0.095
# 2      1        0 days 00:07:37                  0.127
# 3      1 0 days 00:12:08.885000                  0.202
# 4      1 0 days 00:06:51.480000                  0.114
#
#    Listening Time(Minutes)
# 0                    6.283
# 1                    5.683
# 2                    7.617
# 3                   12.133
# 4                    6.850

# %% [markdown]
# Drop columns that are not useful

# %%
spotify_stream_df.drop(columns=["endTime","Time-Played (hh-mm-ss)","msPlayed"], inplace=True)

# %%
spotify_stream_df.drop(spotify_stream_df[spotify_stream_df["artistName"].str.contains("Azeem Azhar's Exponential View")].index, inplace=True)
spotify_stream_df.drop(spotify_stream_df[spotify_stream_df["artistName"].str.contains("The Joe Rogan Experience")].index, inplace=True)
spotify_stream_df.drop(spotify_stream_df[spotify_stream_df["artistName"].str.contains("AI Today Podcast: Artificial Intelligence Insights, Experts, and Opinion")].index, inplace=True)

# %%
spotify_stream_df.describe() # Final check for any abnormality
# Out:
#          year        month          day      weekday        hours   Count  \
# count  9915.0  9915.000000  9915.000000  9915.000000  9915.000000  9915.0
# mean   2021.0     9.675946    14.911851     2.398285    10.876551     1.0
# std       0.0     1.302215     8.530800     1.799462     7.067107     0.0
# min    2021.0     7.000000     1.000000     0.000000     0.000000     1.0
# 25%    2021.0     9.000000     8.000000     1.000000     5.000000     1.0
# 50%    2021.0    10.000000    14.000000     2.000000    10.000000     1.0
# 75%    2021.0    11.000000    22.000000     4.000000    18.000000     1.0
# max    2021.0    12.000000    31.000000     6.000000    23.000000     1.0
#
#        Listening Time(Hours)  Listening Time(Minutes)
# count            9915.000000              9915.000000
# mean                0.046254                 2.727112
# std                 0.055884                 2.462768
# min                 0.000000                 0.000000
# 25%                 0.019000                 1.150000
# 50%                 0.049000                 2.950000
# 75%                 0.059000                 3.567000
# max                 2.037000                57.817000

# %%
top_10_artist_df = spotify_stream_df.groupby(["artistName"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Listening Time(Minutes)",ascending=False)
top_10_artist_df.head(15)
# Out:
#                  Listening Time(Hours)  Listening Time(Minutes)  Count
# artistName
# Amadou & Mariam                  7.907                  474.108    126
# Rema                             7.659                  458.842    163
# Davido                           5.855                  351.474    116
# WizKid                           5.592                  335.593    116
# Burna Boy                        4.547                  273.778    115
# CKay                             4.519                  271.567    107
# Folamour                         4.273                  256.186     58
# KAYTRANADA                       3.662                  219.412    118
# Jhené Aiko                       2.905                  174.200     51
# Adekunle Gold                    2.912                  173.888     68
# Amaarae                          2.862                  171.967     75
# Omah Lay                         2.768                  166.172     75
# Disclosure                       2.706                  162.301     54
# Tems                             2.570                  153.623     55
# Jorja Smith                      2.525                  151.772     60

# %%
top_10_artist_time_df = spotify_stream_df.groupby(["artistName"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Listening Time(Minutes)",ascending=False)
top_10_artist_time_df.head(10)
# Out:
#                  Listening Time(Hours)  Listening Time(Minutes)  Count
# artistName
# Amadou & Mariam                  7.907                  474.108    126
# Rema                             7.659                  458.842    163
# Davido                           5.855                  351.474    116
# WizKid                           5.592                  335.593    116
# Burna Boy                        4.547                  273.778    115
# CKay                             4.519                  271.567    107
# Folamour                         4.273                  256.186     58
# KAYTRANADA                       3.662                  219.412    118
# Jhené Aiko                       2.905                  174.200     51
# Adekunle Gold                    2.912                  173.888     68

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.bar(top_10_artist_time_df.head(10).index,top_10_artist_time_df["Listening Time(Hours)"].head(10),color='green')
ax.set(title="My Top 10 Favourite Artist (based on Hours)",xlabel="Artists",ylabel="No. of Hours Songs Played");
plt.xticks(rotation=90);

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.pie(spotify_stream_df["day-name"].value_counts(), labels=spotify_stream_df["day-name"].value_counts().index, autopct='%1.1f%%', startangle=180, shadow = True);
ax.set(title="Day wise % of Spotify Streaming");

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.set(title="Average Distribution of Streaming Over Day Hours",xlabel="Hours (in 24 hour format)", ylabel="Songs Played")
sns.histplot(spotify_stream_df["hours"], bins=24,kde=True, color="darkgreen");

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.countplot(y=spotify_stream_df["month"], ax=ax)
ax.set(title="Average Spotify Usage over Years", xlabel="Songs Played in Counts", ylabel="Months (Jan-Dec)");

# %%
#Favourite artist playlist recommendation
my_fav_artist_playlist = spotify_stream_df.groupby(["artistName","trackName"])[["Count"]].count().sort_values(by="Count",ascending=False).head(100)

# %%
my_fav_artist_playlist
# Out:
#                                                                        Count
# artistName         trackName
# KAYTRANADA         Vex Oh (feat. Eight9FLY)                               83
# CKay               love nwantiti (ah ah ah) [feat. Joeboy & Kuami ...     64
# Rema               Soundgasm                                              54
# WizKid             Essence (feat. Tems)                                   48
# Adekunle Gold      Okay                                                   43
# ...                                                                      ...
# Neil Chapman Green Absence                                                 9
# Figgy Mold         Stairway to the Stars                                   9
# Kevin Hutchins     South of Lapland                                        9
# KiDi               Touch It                                                9
# De Mthuda          Abekho Ready - Maplankeng Reshuffle                     9
#
# [100 rows x 1 columns]
